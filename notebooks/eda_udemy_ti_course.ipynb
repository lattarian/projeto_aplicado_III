# %% [markdown]
# # **Análise Exploratória**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('udemy_output_All_IT__Software_p1_p626.csv')

df.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
df.shape
# Out:
# (22853, 20)

# %%
df.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22853 entries, 0 to 22852
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            22853 non-null  int64
#  1   title                         22853 non-null  object
#  2   url                           22853 non-null  object
#  3   is_paid                       22853 non-null  bool
#  4   num_subscribers               22853 non-null  int64
#  5   avg_rating                    22853 non-null  float64
#  6   avg_rating_recent             22853 non-null  float64
#  7   rating                        22853 non-null  float64
#  8   num_reviews                   22853 non-null  int64
#  9   is_wishlisted                 22853 non-null  bool
#  10  num_published_lectures        22853 non-null  int64
#  11  num_published_practice_tests  22853 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id  num_subscribers    avg_rating  avg_rating_recent  \
# count  2.285300e+04     22853.000000  22853.000000       22853.000000
# mean   1.818466e+06      3205.448256      3.952356           3.937739
# std    9.273525e+05     11051.296472      0.875152           0.888605
# min    2.762000e+03         0.000000      0.000000           0.000000
# 25%    1.090694e+06        76.000000      3.750000           3.732460
# 50%    1.824268e+06       559.000000      4.150000           4.148680
# 75%    2.604580e+06      2483.000000      4.435480           4.433520
# max    3.486006e+06    564444.000000      5.000000           5.000000
#
#              rating    num_reviews  num_published_lectures  \
# count  22853.000000   22853.000000             22853.00000
# mean       3.937739     270.277557                34.91721
# std        0.888605    2048.788093                48.65282
# min        0.000000       0.000000                 0.00000
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# title                              0
# url                                0
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# is_wishlisted                      0
# num_published_lectures             0
# num_published_practice_tests       0
# created                            0
# published_time                     0
# discount_price__amount          1829
# discount_price__currency        1829
# discount_price__price_string    1829
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# subject_cluster                    0
# dtype: int64

# %% [markdown]
# **More Insights**

# %%
def more_info_to_more_insights(df, column_name):
    df = df.copy()
    max_value = df[column_name].max()
    more_info = df[df[column_name] == max_value]

    print(f"The course with the highest {column_name}:\n"
          f"Course ID: {more_info['id'].iloc[0]}\n"
          f"Course Title: {more_info['title'].iloc[0]}\n"
          f"Rating: {more_info['rating'].iloc[0]}\n"
          f"URL: {more_info['url'].iloc[0]}\n"
          f"Number of Subscribers: {more_info['num_subscribers'].iloc[0]}\n"
          f"Is Paid: {more_info['is_paid'].iloc[0]}\n"
          f"Price: {more_info['price_detail__amount'].iloc[0]}\n"
          f"Number of Reviews: {more_info['num_reviews'].iloc[0]}\n"
          f"Number of Lectures: {more_info['num_published_lectures'].iloc[0]}\n"
          f"Published Timestamp: {more_info['published_time'].iloc[0]}")

# %%
more_info_to_more_insights(df,'num_reviews')
# Out:
# The course with the highest num_reviews:
# Course ID: 362328
# Course Title: AWS Certified Solutions Architect - Associate 2020
# URL: /course/aws-certified-solutions-architect-associate/
# Is Paid: True
# Price: 8640.0
# Number of Reviews: 188941
# Number of Lectures: 136
# Published Timestamp: 2015-01-03

# %%
more_info_to_more_insights(df,'num_subscribers')
# Out:
# The course with the highest num_subscribers:
# Course ID: 362328
# Course Title: AWS Certified Solutions Architect - Associate 2020
# URL: /course/aws-certified-solutions-architect-associate/
# Is Paid: True
# Price: 8640.0
# Number of Reviews: 188941
# Number of Lectures: 136
# Published Timestamp: 2015-01-03

# %%
more_info_to_more_insights(df,'price_detail__amount')
# Out:
# The course with the highest price_detail__amount:
# Course ID: 328266
# Course Title: Project Management Professional (PMP)® - 35 Contact Hours
# URL: /course/pmp-certification-complete/
# Is Paid: True
# Price: 12800.0
# Number of Reviews: 4579
# Number of Lectures: 345
# Published Timestamp: 2014-11-05

# %%
more_info_to_more_insights(df,'rating')
# Out:
# The course with the highest rating:
# Course ID: 1538742
# Course Title: Advanced Upwork Interviews: A Simple Way to Earn High-Pay!
# URL: /course/upwork-interviews/
# Is Paid: True
# Price: 8640.0
# Number of Reviews: 71
# Number of Lectures: 26
# Published Timestamp: 2018-04-25

# %%
top_20 = df.sort_values(by='num_subscribers', ascending=False).head(20)

# Exibe os 20 cursos com mais inscritos
top_20[['title', 'num_subscribers']]
# Out:
#                                                    title  num_subscribers
# 13608  AWS Certified Solutions Architect - Associate ...           564444
# 4      An Entire MBA in 1 Course:Award Winning Busine...           374836
# 13609                 Learn Ethical Hacking From Scratch           372902
# 0      The Complete SQL Bootcamp 2020: Go from Zero t...           295509
# 13614  The Complete Ethical Hacking Course: Beginner ...           277382
# 11484               Stock Market Investing for Beginners           259888
# 3             The Complete Financial Analyst Course 2020           245860
# 13663  Python Bootcamp 2020 Build 15 working Applicat...           243154
# 19     Deep Learning Prerequisites: The Numpy Stack i...           239309
# 1      Tableau 2020 A-Z: Hands-On Tableau Training fo...           209070
# 13766                      Linux for Absolute Beginners!           199833
# 13611           AWS Certified Developer - Associate 2020           193773
# ...
